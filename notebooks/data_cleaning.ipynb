# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np

main_df = pd.read_csv('../data/energy_data.csv')
life_exp = pd.read_excel('../data/life_expectancy.xlsx')
not_in_countries = [country for country in set(main_df['country']) \
                    if country not in set(life_exp['country'])]

# %% [markdown]
# ## Cleaning
# ---
# - Reordering columns
# - Replacing `'--'` with nulls
# - Dropping:
#     - countries not found in the World Bank data, and years 2019 and 2020
#     - countries with null data in columns except  production/consumption_nuclear
# - Converting float data as floats

# %%
# re-ordering columns
cols = main_df.columns.to_list()
cols = cols[:2] + cols[27:28] + cols[32:] + cols[24:27]  + cols[2:24] + cols[28:32]
main_df = main_df[cols]

# %%
# replacing '--' with np.nan
main_df.replace(to_replace = '--', value = np.nan, inplace = True)

# %%
# dropping
drop_index = main_df[(main_df.country.isin(not_in_countries))|
                     (main_df['year']==2019)|
                     (main_df['year']==2020)].index

main_df.drop(index = drop_index, inplace=True)

# after iteratively dropping countries that were giving nulls, identified the following list of
# to drop all at once
drop_countries = ['American Samoa', 'British Virgin Islands','Cyprus','Czech Republic','Eritrea',
                  'Faroe Islands','French Polynesia','Gibraltar','Greenland','Guam','Iceland',
                  'Kosovo','Micronesia','Moldova','Montenegro','Nauru','New Caledonia',
                  'Northern Mariana Islands','Puerto Rico','Serbia','Slovakia','South Sudan',
                  'Timor-Leste','Trinidad and Tobago','Turks and Caicos Islands','Tuvalu',
                  'U.S. Virgin Islands']

drop_index = main_df[(main_df.country.isin(drop_countries)) |
                     (main_df['year'] < 1992) |
                     (main_df['life_expectancy'].isnull())].index

main_df.drop(index = drop_index, inplace = True)

# %%
# converting all float data as float
float_cols = {col:'float64' for col in main_df.columns[2:].to_list()}
main_df = main_df.astype(float_cols)

# %%
# saving progress
main_df.to_csv('../data/cleaned_energy_data.csv', index=False)

main_df
# Out:
#           country  year    population  life_expectancy  \
# 2772        World  1992  5.481774e+06        65.769659
# 2773  Afghanistan  1992  1.448550e+04        51.641000
# 2774      Albania  1992  3.245890e+03        71.802000
# 2775      Algeria  1992  2.702830e+04        67.575000
# 2777       Angola  1992  1.265740e+04        45.230000
# ...           ...   ...           ...              ...
# 9002    Venezuela  2018  2.888713e+04        72.128000
# 9003      Vietnam  2018  9.551330e+04        75.317000
# 9006        Yemen  2018  2.849850e+04        66.096000
# 9007       Zambia  2018  1.736372e+04        63.510000
# 9008     Zimbabwe  2018  1.444540e+04        61.195000
#
#       consumption_per_capita  consumption_per_GDP   ppp_2015USD  \
# 2772               64.426755             6.923158  51013.270526
# 2773                2.159523             1.042253     30.013600
# 2774               25.937798             8.087302     10.410300
# 2775               48.164981             5.592648    232.773000
# 2777                6.689229             1.423070     59.496900
# ...                      ...                  ...           ...
# 9002               91.868677             9.243563    287.099500
# 9003               37.603299             4.198402    855.472000
# 9006                4.336396             2.376919     51.992000
# 9007               12.207614             0.870219    243.581900
# 9008               10.904665             3.847994     40.936200
#
#       production_total  production_coal  production_natural_gas  ...  \
# 2772        353.718416        92.558725               76.984223  ...
# 2773          0.016143         0.000158                0.011092  ...
# 2774          0.065519         0.003415                0.003760  ...
# 2775          5.031036         0.000380                2.325281  ...
# 2777          1.152349         0.000000                0.021076  ...
# ...                ...              ...                     ...  ...
# 9002          4.961309         0.012681                1.028201  ...
# 9003          2.758733         1.115381                0.301613  ...
# 9006          0.103735         0.000000                0.003439  ...
# 9007          0.153048         0.028917                0.000000  ...
# 9008          0.101528         0.053112                0.000000  ...
#
#        imports_coal  imports_electricity  exports_crude_oil  \
# 2772  481679.269000           400.464479          30667.877
# 2773       0.000000             0.131000              0.000
# 2774     104.719450             0.104000              0.000
# 2775    1139.243484             0.125000            279.400
# 2777       0.000000             0.000000            508.400
# ...             ...                  ...                ...
# 9002       4.086969             0.000000           1002.677
# 9003   25541.550070             3.124000             66.880
# 9006     136.686440             0.000000              0.000
# 9007      97.105841             0.152000              0.000
# 9008      18.691566             1.177000              0.000
#
#       exports_natural_gas   exports_coal  exports_electricity  \
# 2772          17854.85234  494096.467500           400.795117
# 2773              0.00000       0.000000             0.000000
# 2774              0.00000       0.000000             0.560000
# 2775           1240.61590       0.000000             1.061000
# 2777              0.00000       0.000000             0.000000
# ...                   ...            ...                  ...
# 9002              0.00000      96.077120             1.023000
# 9003              0.00000    1922.007365             1.509000
# 9006              0.00000       0.000000             0.000000
# 9007              0.00000       2.994003             1.225000
# 9008              0.00000     107.873200             0.161000
#
#       emissions_co2_emissions  emissions_coal_and_coke  \
# 2772             22529.424264              8587.186368
# 2773                 1.704078                 0.015551
# 2774                 3.901890                 0.502372
# 2775                74.390488                 2.687475
# 2777                 5.218203                 0.000000
# ...                       ...                      ...
# 9002               128.298044                 0.127186
# 9003               240.322623               158.668579
# 9006                 8.368932                 0.297799
# 9007                 7.143270                 2.894102
# 9008                 8.935401                 4.588967
#
#       emissions_consumed_natural_gas  emissions_petroleum_and_other_liquids
# 2772                     4076.853622                            9865.384274
# 2773                        0.588528                               1.100000
# 2774                        0.199519                               3.200000
# 2775                       45.703013                              26.000000
# 2777                        1.118203                               4.100000
# ...                              ...                                    ...
# 9002                       51.365908                              76.804951
# 9003                       15.837385                              65.816659
# 9006                        0.182775                               7.888358
# 9007                        0.000000                               4.249168
# 9008                        0.000000                               4.346435
#
# [4724 rows x 33 columns]

# %%
main_df.isnull().sum()
# Out:
# country                                        0
# year                                           0
# population                                     0
# life_expectancy                                0
# consumption_per_capita                         0
# consumption_per_GDP                            0
# ppp_2015USD                                    0
# production_total                               0
# production_coal                                0
# production_natural_gas                         0
# production_petrolium_and_other_liquids         0
# production_nuclear                          3942
# production_nuclear_renewables_and_other        0
# production_renewables_and_other                0
# consumption_total                              0
# consumption_coal                               0
# consumption_natural_gas                        0
# consumption_petrolium_and_other_liquids        0
# consumption_nuclear                         3942
# consumption_nuclear_renewables_and_other       0
# consumption_renewables_and_other               0
# imports_crude_oil                              0
# imports_natural_gas                            0
# imports_coal                                   0
# imports_electricity                            0
# exports_crude_oil                              0
# exports_natural_gas                            0
# exports_coal                                   0
# exports_electricity                            0
# emissions_co2_emissions                        0
# emissions_coal_and_coke                        0
# emissions_consumed_natural_gas                 0
# emissions_petroleum_and_other_liquids          0
# dtype: int64
